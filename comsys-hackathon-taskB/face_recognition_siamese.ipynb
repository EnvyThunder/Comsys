0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Cesar_Maia_0002.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Chance_Mock_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Chandrika_Kumaratunga_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Chang_Jae_On_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Charles_Lebois_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Charles_Mathews_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Charles_Mathews_0002.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Charles_Pickering_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Charles_Richardson_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Charles_Schumer_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Charles_Schumer_0002.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Charlie_Hunnam_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Charlton_Heston_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Charlton_Heston_0002.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Charlton_Heston_0003.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Charlton_Heston_0004.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Charlton_Heston_0005.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Charlton_Heston_0006.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Chea_Sophara_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Chin-Feng_Chen_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Chip_Ganassi_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Cho_Myung-kyun_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Christian_Longo_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Christian_Longo_0002.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Christian_Longo_0003.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Chris_Cirino_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Chris_Kolanas_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Chris_Moore_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Chris_Rock_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Chris_Rock_0002.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Chuck_Eidson_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Chung_Mong-hun_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Chung_Mong-hun_0002.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Ciro_Gomes_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Ciro_Gomes_0002.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Ciro_Gomes_0003.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Ciro_Gomes_0004.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Ciro_Gomes_0005.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Claudia_Cardinale_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Claudio_Abbado_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Clemente_de_la_Vega_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Clive_Lloyd_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0001.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0002.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0003.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0004.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0005.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0006.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0007.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0008.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0009.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0010.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0011.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0012.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0013.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0014.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0015.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0016.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0017.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0018.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0019.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0020.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0021.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0022.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0023.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0024.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0025.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0026.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0027.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0028.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0029.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0030.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0031.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0032.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0033.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0034.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0035.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0036.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0037.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0038.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0039.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0040.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0041.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0042.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0043.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0044.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0045.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0046.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0047.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0048.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0049.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0050.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0051.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0052.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0053.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0054.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0055.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0056.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0057.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0058.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0059.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0060.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0061.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0062.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0063.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0064.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0065.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0066.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0067.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0068.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0069.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0070.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0071.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0072.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0073.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0074.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0075.jpg
#   inflating: Comys_Hackathon5/Task_A/train/male/Colin_Powell_0076.jpg
# ...
#   inflating: Comys_Hackathon5/Task_B/val/Warren_Beatty/Warren_Beatty_0002.jpg
#    creating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/
#    creating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0001_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0001_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0001_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0001_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0001_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0001_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0001_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0002_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0002_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0002_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0002_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0002_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0002_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0002_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0003_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0003_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0003_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0003_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0003_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0003_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0003_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0004_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0004_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0004_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0004_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0004_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0004_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0004_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0005_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0005_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0005_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0005_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0005_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0005_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0005_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0006_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0006_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0006_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0006_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0006_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0006_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0006_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0007_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0007_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0007_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0007_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0007_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0007_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0007_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0008_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0008_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0008_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0008_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0008_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0008_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0008_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0009_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0009_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0009_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0009_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0009_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0009_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0009_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0010_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0010_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0010_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0010_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0010_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0010_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0010_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0011_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0011_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0011_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0011_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0011_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0011_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0011_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0012_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0012_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0012_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0012_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0012_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0012_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0012_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0013_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0013_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0013_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0013_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0013_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0013_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/distortion/Wen_Jiabao_0013_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/Wen_Jiabao_0001.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/Wen_Jiabao_0002.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/Wen_Jiabao_0003.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/Wen_Jiabao_0004.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/Wen_Jiabao_0005.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/Wen_Jiabao_0006.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/Wen_Jiabao_0007.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/Wen_Jiabao_0008.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/Wen_Jiabao_0009.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/Wen_Jiabao_0010.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/Wen_Jiabao_0011.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/Wen_Jiabao_0012.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Wen_Jiabao/Wen_Jiabao_0013.jpg
#    creating: Comys_Hackathon5/Task_B/val/William_Cocksedge/
#    creating: Comys_Hackathon5/Task_B/val/William_Cocksedge/distortion/
#   inflating: Comys_Hackathon5/Task_B/val/William_Cocksedge/distortion/William_Cocksedge_0001_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Cocksedge/distortion/William_Cocksedge_0001_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Cocksedge/distortion/William_Cocksedge_0001_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Cocksedge/distortion/William_Cocksedge_0001_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Cocksedge/distortion/William_Cocksedge_0001_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Cocksedge/distortion/William_Cocksedge_0001_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Cocksedge/distortion/William_Cocksedge_0001_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Cocksedge/William_Cocksedge_0001.jpg
#    creating: Comys_Hackathon5/Task_B/val/William_Delahunt/
#    creating: Comys_Hackathon5/Task_B/val/William_Delahunt/distortion/
#   inflating: Comys_Hackathon5/Task_B/val/William_Delahunt/distortion/William_Delahunt_0001_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Delahunt/distortion/William_Delahunt_0001_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Delahunt/distortion/William_Delahunt_0001_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Delahunt/distortion/William_Delahunt_0001_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Delahunt/distortion/William_Delahunt_0001_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Delahunt/distortion/William_Delahunt_0001_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Delahunt/distortion/William_Delahunt_0001_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Delahunt/William_Delahunt_0001.jpg
#    creating: Comys_Hackathon5/Task_B/val/William_Genego/
#    creating: Comys_Hackathon5/Task_B/val/William_Genego/distortion/
#   inflating: Comys_Hackathon5/Task_B/val/William_Genego/distortion/William_Genego_0001_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Genego/distortion/William_Genego_0001_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Genego/distortion/William_Genego_0001_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Genego/distortion/William_Genego_0001_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Genego/distortion/William_Genego_0001_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Genego/distortion/William_Genego_0001_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Genego/distortion/William_Genego_0001_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/William_Genego/William_Genego_0001.jpg
#    creating: Comys_Hackathon5/Task_B/val/Will_Ferrell/
#    creating: Comys_Hackathon5/Task_B/val/Will_Ferrell/distortion/
#   inflating: Comys_Hackathon5/Task_B/val/Will_Ferrell/distortion/Will_Ferrell_0001_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Will_Ferrell/distortion/Will_Ferrell_0001_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Will_Ferrell/distortion/Will_Ferrell_0001_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Will_Ferrell/distortion/Will_Ferrell_0001_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Will_Ferrell/distortion/Will_Ferrell_0001_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Will_Ferrell/distortion/Will_Ferrell_0001_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Will_Ferrell/distortion/Will_Ferrell_0001_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Will_Ferrell/Will_Ferrell_0001.jpg
#    creating: Comys_Hackathon5/Task_B/val/Woodrow_Stanley/
#    creating: Comys_Hackathon5/Task_B/val/Woodrow_Stanley/distortion/
#   inflating: Comys_Hackathon5/Task_B/val/Woodrow_Stanley/distortion/Woodrow_Stanley_0001_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Woodrow_Stanley/distortion/Woodrow_Stanley_0001_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Woodrow_Stanley/distortion/Woodrow_Stanley_0001_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Woodrow_Stanley/distortion/Woodrow_Stanley_0001_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Woodrow_Stanley/distortion/Woodrow_Stanley_0001_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Woodrow_Stanley/distortion/Woodrow_Stanley_0001_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Woodrow_Stanley/distortion/Woodrow_Stanley_0001_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Woodrow_Stanley/Woodrow_Stanley_0001.jpg
#    creating: Comys_Hackathon5/Task_B/val/Yoelbi_Quesada/
#    creating: Comys_Hackathon5/Task_B/val/Yoelbi_Quesada/distortion/
#   inflating: Comys_Hackathon5/Task_B/val/Yoelbi_Quesada/distortion/Yoelbi_Quesada_0001_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Yoelbi_Quesada/distortion/Yoelbi_Quesada_0001_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Yoelbi_Quesada/distortion/Yoelbi_Quesada_0001_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Yoelbi_Quesada/distortion/Yoelbi_Quesada_0001_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Yoelbi_Quesada/distortion/Yoelbi_Quesada_0001_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Yoelbi_Quesada/distortion/Yoelbi_Quesada_0001_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Yoelbi_Quesada/distortion/Yoelbi_Quesada_0001_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Yoelbi_Quesada/Yoelbi_Quesada_0001.jpg
#    creating: Comys_Hackathon5/Task_B/val/Yoon_Young-kwan/
#    creating: Comys_Hackathon5/Task_B/val/Yoon_Young-kwan/distortion/
#   inflating: Comys_Hackathon5/Task_B/val/Yoon_Young-kwan/distortion/Yoon_Young-kwan_0001_blurred.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Yoon_Young-kwan/distortion/Yoon_Young-kwan_0001_foggy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Yoon_Young-kwan/distortion/Yoon_Young-kwan_0001_lowlight.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Yoon_Young-kwan/distortion/Yoon_Young-kwan_0001_noisy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Yoon_Young-kwan/distortion/Yoon_Young-kwan_0001_rainy.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Yoon_Young-kwan/distortion/Yoon_Young-kwan_0001_resized.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Yoon_Young-kwan/distortion/Yoon_Young-kwan_0001_sunny.jpg
#   inflating: Comys_Hackathon5/Task_B/val/Yoon_Young-kwan/Yoon_Young-kwan_0001.jpg

# %%
# !ls /kaggle/working/Comys_Hackathon5/Task_B
# Out:
# train  val

# %%
import os
import random
import shutil
import numpy as np
from PIL import Image
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import GradScaler, autocast

import albumentations as A
from albumentations.pytorch import ToTensorV2
import timm
from sklearn.metrics import precision_score, recall_score, f1_score

# ======================== Seeding ========================
def seed_everything(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(42)

# ======================== Device ========================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# ================== Flatten distortion folders ==================
def flatten_distortion_folders(root_dir):
    for class_name in os.listdir(root_dir):
        class_path = os.path.join(root_dir, class_name)
        distortion_path = os.path.join(class_path, "distortion")
        if os.path.isdir(distortion_path):
            for img_file in os.listdir(distortion_path):
                src = os.path.join(distortion_path, img_file)
                dst = os.path.join(class_path, img_file)
                if os.path.isfile(src):
                    shutil.move(src, dst)
            os.rmdir(distortion_path)

# ================== Siamese Dataset ==================
class SiameseDistortionDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = sorted(os.listdir(root_dir))
        self.image_paths = {
            cls: sorted([
                os.path.join(root_dir, cls, img)
                for img in os.listdir(os.path.join(root_dir, cls))
                if os.path.isfile(os.path.join(root_dir, cls, img))
            ]) for cls in self.classes
        }

        self.pairs = []
        self.labels = []
        for cls in self.classes:
            same_class_imgs = self.image_paths[cls]
            for i in range(len(same_class_imgs) - 1):
                self.pairs.append((same_class_imgs[i], same_class_imgs[i + 1]))
                self.labels.append(1)
                other_classes = [c for c in self.classes if c != cls]
                random.shuffle(other_classes)
                for diff_cls in other_classes:
                    if self.image_paths[diff_cls]:
                        diff_img = self.image_paths[diff_cls][i % len(self.image_paths[diff_cls])]
                        self.pairs.append((same_class_imgs[i], diff_img))
                        self.labels.append(0)
                        break

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        img1_path, img2_path = self.pairs[idx]
        label = torch.tensor(self.labels[idx], dtype=torch.float32)
        img1 = np.array(Image.open(img1_path).convert('RGB'))
        img2 = np.array(Image.open(img2_path).convert('RGB'))
        if self.transform:
            img1 = self.transform(image=img1)['image']
            img2 = self.transform(image=img2)['image']
        return img1, img2, label

# ================== Model ==================
class SiameseNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = timm.create_model('convnext_atto', pretrained=True, num_classes=0)
        self.projection = nn.Sequential(
            nn.Linear(self.encoder.num_features, 512),
            nn.ReLU(),
            nn.Linear(512, 128)
        )

    def forward_once(self, x):
        feat = self.encoder(x)
        feat = self.projection(feat)
        feat = F.normalize(feat, p=2, dim=1)
        return feat

    def forward(self, x1, x2):
        return self.forward_once(x1), self.forward_once(x2)

# ================== Loss ==================
class ContrastiveLoss(nn.Module):
    def __init__(self, margin=1.0):
        super().__init__()
        self.margin = margin

    def forward(self, feat1, feat2, label):
        distance = F.pairwise_distance(feat1, feat2)
        loss = label * distance.pow(2) + (1 - label) * (torch.clamp(self.margin - distance, min=0.0).pow(2))
        return loss.mean()

# ================== Metric Computation ==================
def compute_all_metrics(preds, labels):
    preds_np = np.array(preds)
    labels_np = np.array(labels)
    acc = (preds_np == labels_np).mean()
    precision = precision_score(labels_np, preds_np, zero_division=0)
    recall = recall_score(labels_np, preds_np, zero_division=0)
    f1 = f1_score(labels_np, preds_np, zero_division=0)
    return acc, precision, recall, f1

# ================== Copy Data ==================
train = "/kaggle/working/Comys_Hackathon5/Task_B/train"
val = "/kaggle/working/Comys_Hackathon5/Task_B/val"
flatten_distortion_folders(train)
flatten_distortion_folders(val)

# ================== Transforms ==================
train_transform = A.Compose([
    A.Resize(224, 224),
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.2),
    A.HueSaturationValue(p=0.2),
    A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.05, rotate_limit=15, p=0.5),
    A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
    ToTensorV2()
])

val_transform = A.Compose([
    A.Resize(224, 224),
    A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
    ToTensorV2()
])

# ================== Dataloaders ==================
g = torch.Generator()
g.manual_seed(42)

train_dataset = SiameseDistortionDataset(root_dir=train, transform=train_transform)
val_dataset = SiameseDistortionDataset(root_dir=val, transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, generator=g, num_workers=2, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2, pin_memory=True)

# ================== Training ==================
model = SiameseNet().to(device)
criterion = ContrastiveLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
scaler = GradScaler()

best_acc = 0
patience = 5
counter = 0

for epoch in range(20):
    model.train()
    all_train_preds, all_train_labels = [], []
    total_train_loss = 0
    for img1, img2, label in tqdm(train_loader, desc=f"[Train] Epoch {epoch+1}/20"):
        img1, img2, label = img1.to(device), img2.to(device), label.to(device)
        optimizer.zero_grad()
        with autocast():
            feat1, feat2 = model(img1, img2)
            loss = criterion(feat1, feat2, label)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        total_train_loss += loss.item()
        with torch.no_grad():
            distance = F.pairwise_distance(feat1, feat2)
            preds = (distance < 0.5).float()
            all_train_preds.extend(preds.cpu().numpy())
            all_train_labels.extend(label.cpu().numpy())

    train_acc, train_prec, train_recall, train_f1 = compute_all_metrics(all_train_preds, all_train_labels)
    avg_train_loss = total_train_loss / len(train_loader)

    model.eval()
    all_val_preds, all_val_labels = [], []
    total_val_loss = 0
    with torch.no_grad():
        for img1, img2, label in tqdm(val_loader, desc=f"[Val] Epoch {epoch+1}/20"):
            img1, img2, label = img1.to(device), img2.to(device), label.to(device)
            feat1, feat2 = model(img1, img2)
            loss = criterion(feat1, feat2, label)
            total_val_loss += loss.item()

            distance = F.pairwise_distance(feat1, feat2)
            preds = (distance < 0.5).float()
            all_val_preds.extend(preds.cpu().numpy())
            all_val_labels.extend(label.cpu().numpy())

    val_acc, val_prec, val_recall, val_f1 = compute_all_metrics(all_val_preds, all_val_labels)
    avg_val_loss = total_val_loss / len(val_loader)

    print(f"Epoch {epoch+1}: Train Loss={avg_train_loss:.4f}, Train Acc={train_acc:.4f}, Precision={train_prec:.4f}, Recall={train_recall:.4f}, F1={train_f1:.4f}")
    print(f"Epoch {epoch+1}: Val Loss={avg_val_loss:.4f}, Val Acc={val_acc:.4f}, Precision={val_prec:.4f}, Recall={val_recall:.4f}, F1={val_f1:.4f}\n")

    if val_acc > best_acc:
        best_acc = val_acc
        torch.save(model.state_dict(), '/kaggle/working/best_siamese_convnext.pt')
        counter = 0
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping triggered.")
            break

    scheduler.step()
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:87: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /tmp/ipykernel_35/2902543553.py:168: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# [Train] Epoch 1/20:   0%|          | 0/909 [00:00<?, ?it/s]/tmp/ipykernel_35/2902543553.py:181: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train] Epoch 1/20:   6%|▌         | 52/909 [00:29<08:02,  1.78it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_35/2902543553.py in <cell line: 0>()
#     182             feat1, feat2 = model(img1, img2)
#     183             loss = criterion(feat1, feat2, label)
# --> 184         scaler.scale(loss).backward()
#     185         scaler.step(optimizer)
#     186         scaler.update()
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     624                 inputs=inputs,
#     625             )
# --> 626         torch.autograd.backward(
#     627             self, gradient, retain_graph, create_graph, inputs=inputs
#     628         )
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     821         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822     try:
# --> 823         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824             t_outputs, *args, **kwargs
#     825         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:
